# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
music_df=pd.read_csv('../data/mlc_sample.csv')

# %%
music_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 13 columns):
#  #   Column                                     Non-Null Count   Dtype
# ---  ------                                     --------------   -----
#  0   ISRC                                       98240 non-null   object
#  1   Country Code                               98303 non-null   object
#  2   Registrant Code                            98303 non-null   object
#  3   Year of Reference                          98239 non-null   float64
#  4   Usage Period                               91898 non-null   object
#  5   Streaming Platform (DSP)                   96001 non-null   object
#  6   Streams                                    100000 non-null  object
#  7   Recording Artist                           100000 non-null  object
#  8   Recording Label                            98992 non-null   object
#  9   Recording Title                            100000 non-null  object
#  10  Release Title                              99931 non-null   object
#  11  Recording Duration (Seconds)               100000 non-null  int64
#  12  Songwriter's Listed (1 = "Yes", 0 = "No")  100000 non-null  int64
# dtypes: float64(1), int64(2), object(10)
# memory usage: 9.9+ MB

# %%
music_df.rename(columns={'If ': 'ISRC'})
# Out:
#                ISRC Country Code Registrant Code  Year of Reference  \
# 0      USUG12101043           US             UG1               21.0
# 1      USRC12100543           US             RC1               21.0
# 2      USSM12102263           US             SM1               21.0
# 3      USLD91731547           US             LD9               17.0
# 4      USAT22007048           US             AT2               20.0
# ...             ...          ...             ...                ...
# 99995  QZK6F2019397           QZ             K6F               20.0
# 99996  QZK6F2019397           QZ             K6F               20.0
# 99997  SE6HN1926755           SE             6HN               19.0
# 99998  SEYOK1669274           SE             YOK               16.0
# 99999  QZK6F2019397           QZ             K6F               20.0
#
#       Usage Period Streaming Platform (DSP)  Streams        Recording Artist  \
# 0              NaN                AudioMack   10,175                  Future
# 1              NaN               SoundCloud    8,597                LUCKY3RD
# 2              NaN               SoundCloud  261,280                LUCKY3RD
# 3         2/1/2021                   Trebel        5  Bachata & Merengue Mix
# 4              NaN                AudioMack   62,105                  Foolio
# ...            ...                      ...      ...                     ...
# 99995     3/1/2021                  Spotify   28,549                    Myuk
# 99996     3/1/2021                  Spotify   28,941                    yama
# 99997     3/1/2021                  Spotify   28,941                    yama
# 99998     3/1/2021                    Apple    8,970                    yama
# 99999     2/1/2021                  Spotify   11,245               Lexie Liu
#
#               Recording Label                            Recording Title  \
# 0                         NaN   FUTURE FT DEJ LOAF HEY THERE PROD BY DDS
# 1                    LUCKY3RD                     Keep It Cool  LUCKY3RD
# 2                    LUCKY3RD                     Life Goes On  LUCKY3RD
# 3                     Orchard     No dudes de mi- Merengue & Bachata Mix
# 4                         NaN                       WHEN I SEE YOU REMIX
# ...                       ...                                        ...
# 99995  Sony Music Labels Inc.                            魔法 - Anime Size
# 99996  Sony Music Labels Inc.                                         麻痺
# 99997  Sony Music Labels Inc.                                         麻痺
# 99998  Sony Music Labels Inc.                                         麻痺
# 99999          泥鞋（北京）文化传媒有限公司                              黑洞 Metropolis
#
#                  Release Title  Recording Duration (Seconds)  \
# 0                    #unknown#                           181
# 1       Keep It Cool  LUCKY3RD                           133
# 2       Life Goes On  LUCKY3RD                           171
# 3                Mega Mix 2010                          1250
# 4                    #unknown#                           187
# ...                        ...                           ...
# 99995          魔法 (Anime Size)                            89
# 99996                       麻痺                           199
# 99997                       麻痺                           199
# 99998              麻痺 - Single                           198
# 99999            无限意识 Meta Ego                           259
#
#        Songwriter's Listed (1 = "Yes", 0 = "No")
# 0                                              0
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
# ...                                          ...
# 99995                                          1
# 99996                                          1
# 99997                                          1
# 99998                                          1
# 99999                                          1
#
# [100000 rows x 13 columns]

# %%
music_df["ISRC"].fillna(" ", inplace = True)
music_df["Country Code"].fillna(" ", inplace = True)
music_df["Registrant Code"].fillna(" ", inplace = True)
music_df["Year of Reference"].fillna(" ", inplace = True)
music_df["Usage Period"].fillna(" ", inplace = True)
music_df["Streaming Platform (DSP)"].fillna(" ", inplace = True)
music_df["Streams"].fillna(" ", inplace = True)
music_df["Recording Artist"].fillna(" ", inplace = True)
music_df["Recording Label"].fillna(" ", inplace = True)
music_df["Recording Title"].fillna(" ", inplace = True)
music_df["Release Title"].fillna(" ", inplace = True)
music_df["Recording Duration (Seconds)"].fillna(" ", inplace = True)

# %%
music_df=music_df.set_axis(["ISRC","Country","Registrant","Year","UsePeriod","Platform","Streams","Artist","Label","RecordingName","ReleaseName","Length","ListsWriters"], axis=1)

# %%
music_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 13 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   ISRC           100000 non-null  object
#  1   Country        100000 non-null  object
#  2   Registrant     100000 non-null  object
#  3   Year           100000 non-null  object
#  4   UsePeriod      100000 non-null  object
#  5   Platform       100000 non-null  object
#  6   Streams        100000 non-null  object
#  7   Artist         100000 non-null  object
#  8   Label          100000 non-null  object
#  9   RecordingName  100000 non-null  object
#  10  ReleaseName    100000 non-null  object
#  11  Length         100000 non-null  int64
#  12  ListsWriters   100000 non-null  int64
# dtypes: int64(2), object(11)
# memory usage: 9.9+ MB

# %%
music_df.isnull().sum() #checks for null values across whole df
# Out:
# ISRC             0
# Country          0
# Registrant       0
# Year             0
# UsePeriod        0
# Platform         0
# Streams          0
# Artist           0
# Label            0
# RecordingName    0
# ReleaseName      0
# Length           0
# ListsWriters     0
# dtype: int64

# %%
music_df.head()
# Out:
#            ISRC Country Registrant  Year UsePeriod    Platform  Streams  \
# 0  USUG12101043      US        UG1  21.0             AudioMack   10,175
# 1  USRC12100543      US        RC1  21.0            SoundCloud    8,597
# 2  USSM12102263      US        SM1  21.0            SoundCloud  261,280
# 3  USLD91731547      US        LD9  17.0  2/1/2021      Trebel        5
# 4  USAT22007048      US        AT2  20.0             AudioMack   62,105
#
#                    Artist     Label  \
# 0                  Future
# 1                LUCKY3RD  LUCKY3RD
# 2                LUCKY3RD  LUCKY3RD
# 3  Bachata & Merengue Mix   Orchard
# 4                  Foolio
#
#                                RecordingName              ReleaseName  Length  \
# 0   FUTURE FT DEJ LOAF HEY THERE PROD BY DDS                #unknown#     181
# 1                     Keep It Cool  LUCKY3RD   Keep It Cool  LUCKY3RD     133
# 2                     Life Goes On  LUCKY3RD   Life Goes On  LUCKY3RD     171
# 3     No dudes de mi- Merengue & Bachata Mix            Mega Mix 2010    1250
# 4                       WHEN I SEE YOU REMIX                #unknown#     187
#
#    ListsWriters
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
music_df['Streams'] = music_df['Streams'].astype(str) #convert streams to string in order to replace comma
music_df['Streams']=music_df['Streams'].str.replace(',','') #replace comma with nothing
music_df['Streams'] = music_df['Streams'].astype(int) #convert to integer

# %%
music_df.head()
# Out:
#            ISRC Country Registrant  Year UsePeriod    Platform  Streams  \
# 0  USUG12101043      US        UG1  21.0             AudioMack    10175
# 1  USRC12100543      US        RC1  21.0            SoundCloud     8597
# 2  USSM12102263      US        SM1  21.0            SoundCloud   261280
# 3  USLD91731547      US        LD9  17.0  2/1/2021      Trebel        5
# 4  USAT22007048      US        AT2  20.0             AudioMack    62105
#
#                    Artist     Label  \
# 0                  Future
# 1                LUCKY3RD  LUCKY3RD
# 2                LUCKY3RD  LUCKY3RD
# 3  Bachata & Merengue Mix   Orchard
# 4                  Foolio
#
#                                RecordingName              ReleaseName  Length  \
# 0   FUTURE FT DEJ LOAF HEY THERE PROD BY DDS                #unknown#     181
# 1                     Keep It Cool  LUCKY3RD   Keep It Cool  LUCKY3RD     133
# 2                     Life Goes On  LUCKY3RD   Life Goes On  LUCKY3RD     171
# 3     No dudes de mi- Merengue & Bachata Mix            Mega Mix 2010    1250
# 4                       WHEN I SEE YOU REMIX                #unknown#     187
#
#    ListsWriters
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
test=music_df.loc[(music_df['Label']==' ')] #testing the difference between '' and ' ' -> I need to use ' ' to find blanks
test.head()
# Out:
#              ISRC Country Registrant  Year UsePeriod   Platform  Streams  \
# 0    USUG12101043      US        UG1  21.0            AudioMack    10175
# 4    USAT22007048      US        AT2  20.0            AudioMack    62105
# 138  USUYG1360358      US        UYG  13.0  4/1/2021     Deezer        2
# 139  USUM72105617      US        UM7  21.0  4/1/2021     Deezer        2
# 140  USAT22007802      US        AT2  20.0  5/1/2021     Deezer        2
#
#       Artist Label                              RecordingName  \
# 0     Future         FUTURE FT DEJ LOAF HEY THERE PROD BY DDS
# 4     Foolio                             WHEN I SEE YOU REMIX
# 138  Unknown                                      {Cartagena}
# 139  Unknown                                      {Esa Mujer}
# 140  Unknown                                      {Esa Mujer}
#
#                             ReleaseName  Length  ListsWriters
# 0                             #unknown#     181             0
# 4                             #unknown#     187             0
# 138  Silvestre Dangond - Grandes Éxitos  356461             0
# 139  Silvestre Dangond - Grandes Éxitos  356461             0
# 140  Silvestre Dangond - Grandes Éxitos  356461             0

# %%
maybe_indie=music_df.loc[(music_df['Artist']==music_df['Label']) | (music_df['Label']==' ')] #filtering to only artists that are potentially independent or not represented by a label because the label is blank

# %%
maybe_indie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12067 entries, 0 to 99940
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ISRC           12067 non-null  object
#  1   Country        12067 non-null  object
#  2   Registrant     12067 non-null  object
#  3   Year           12067 non-null  object
#  4   UsePeriod      12067 non-null  object
#  5   Platform       12067 non-null  object
#  6   Streams        12067 non-null  int32
#  7   Artist         12067 non-null  object
#  8   Label          12067 non-null  object
#  9   RecordingName  12067 non-null  object
#  10  ReleaseName    12067 non-null  object
#  11  Length         12067 non-null  int64
#  12  ListsWriters   12067 non-null  int64
# dtypes: int32(1), int64(2), object(10)
# memory usage: 1.2+ MB

# %%
not_indie = music_df.loc[(music_df['Artist']!=music_df['Label'])& (music_df['Label']!=' ')]
#finding rows where the artist is potentially represented by a not-independent label because artist <> label and the label is not blank 
#in the previous step i included artists where the label *is* blank so here I should exclude them 
not_indie.head()
# Out:
#            ISRC Country Registrant  Year UsePeriod Platform  Streams  \
# 3  USLD91731547      US        LD9  17.0  2/1/2021   Trebel        5
# 6  USUG12100126      US        UG1  21.0  3/1/2021    Apple     5839
# 7  QMJMT2103634      QM        JMT  21.0  2/1/2021   Amazon     7842
# 8  USRC12100543      US        RC1  21.0  3/1/2021  Spotify    28419
# 9  USAT22007048      US        AT2  20.0  3/1/2021  Spotify    28419
#
#                    Artist            Label  \
# 3  Bachata & Merengue Mix          Orchard
# 6          Quentin Miller  1317 Recordings
# 7                      NF    NF Real Music
# 8                  2worth     die happy <3
# 9                  2worth     die happy <3
#
#                              RecordingName          ReleaseName  Length  \
# 3   No dudes de mi- Merengue & Bachata Mix        Mega Mix 2010    1250
# 6                         _A_ (feat. Pe$o)                 Q.M.     199
# 7                              -Interlude-           The Search      49
# 8                      ¡!gu4na:D////:>_<^^  ¡!gu4na:D////:>_<^^     126
# 9                      ¡!gu4na:D////:>_<^^  ¡!gu4na:D////:>_<^^     126
#
#    ListsWriters
# 3             0
# 6             1
# 7             0
# 8             1
# 9             1

# %%
indie = filtered_music[~filtered_music.Label.isin(common.Label)]

# %%
indie.head()
# Out:
#             ISRC Country Registrant  Year UsePeriod    Platform  Streams  \
# 1   USRC12100543      US        RC1  21.0            SoundCloud     8597
# 2   USSM12102263      US        SM1  21.0            SoundCloud   261280
# 5   QZJ842000983      QZ        J84  20.0  3/1/2021     Spotify     8133
# 20  TCAFA2064435      TC        AFA  20.0  3/1/2021     Spotify    14496
# 21  USUG12100638      US        UG1  21.0  1/1/2021     Pandora    16935
#
#                       Artist                     Label  \
# 1                   LUCKY3RD                  LUCKY3RD
# 2                   LUCKY3RD                  LUCKY3RD
# 5                     x0o0x_                    x0o0x_
# 20  Daniel, Me Estás Matando  Daniel, Me Estás Matando
# 21         Cultura Profética         Cultura Profética
#
#                                         RecordingName  \
# 1                              Keep It Cool  LUCKY3RD
# 2                              Life Goes On  LUCKY3RD
# 5                                              ______
# 20                ¿Qué Se Siente Que Me Gustes Tanto?
# 21  ¿Qué Será? / Ritmo Que Pesa / Suelta los Amarr...
#
#                                           ReleaseName  Length  ListsWriters
# 1                              Keep It Cool  LUCKY3RD     133             0
# 2                              Life Goes On  LUCKY3RD     171             0
# 5                                              ______     142             0
# 20                                           Suspiros     185             1
# 21  Single::¿Qué Será? / Ritmo Que Pesa / Suelta l...     834             0
