# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
music_df=pd.read_csv('../data/mlc_data.csv')

# %%
music_df = music_df.rename(columns={'If ': 'ISRC'})

# %%
music_df["ISRC"].fillna(" ", inplace = True)
music_df["Country Code"].fillna(" ", inplace = True)
music_df["Registrant Code"].fillna(" ", inplace = True)
music_df["Year of Reference"].fillna(" ", inplace = True)
music_df["Usage Period"].fillna(" ", inplace = True)
music_df["Streaming Platform (DSP)"].fillna(" ", inplace = True)
music_df["Streams"].fillna(" ", inplace = True)
music_df["Recording Artist"].fillna(" ", inplace = True)
music_df["Recording Label"].fillna(" ", inplace = True)
music_df["Recording Title"].fillna(" ", inplace = True)
music_df["Release Title"].fillna(" ", inplace = True)
music_df["Recording Duration (Seconds)"].fillna(" ", inplace = True)

# %%
music_df=music_df.set_axis(["ISRC","Country","Registrant","Year","UsePeriod","Platform","Streams","Artist","Label","RecordingName","ReleaseName","Length","ListsWriters"], axis=1)

# %%
music_df
# Out:
#                ISRC Country Registrant  Year UsePeriod    Platform  Streams  \
# 0      USUG12101043      US        UG1  21.0             AudioMack   10,175
# 1      USRC12100543      US        RC1  21.0            SoundCloud    8,597
# 2      USSM12102263      US        SM1  21.0            SoundCloud  261,280
# 3      USLD91731547      US        LD9  17.0  2/1/2021      Trebel        5
# 4      USAT22007048      US        AT2  20.0             AudioMack   62,105
# ...             ...     ...        ...   ...       ...         ...      ...
# 99995  QZK6F2019397      QZ        K6F  20.0  3/1/2021     Spotify   28,549
# 99996  QZK6F2019397      QZ        K6F  20.0  3/1/2021     Spotify   28,941
# 99997  SE6HN1926755      SE        6HN  19.0  3/1/2021     Spotify   28,941
# 99998  SEYOK1669274      SE        YOK  16.0  3/1/2021       Apple    8,970
# 99999  QZK6F2019397      QZ        K6F  20.0  2/1/2021     Spotify   11,245
#
#                        Artist                   Label  \
# 0                      Future
# 1                    LUCKY3RD                LUCKY3RD
# 2                    LUCKY3RD                LUCKY3RD
# 3      Bachata & Merengue Mix                 Orchard
# 4                      Foolio
# ...                       ...                     ...
# 99995                    Myuk  Sony Music Labels Inc.
# 99996                    yama  Sony Music Labels Inc.
# 99997                    yama  Sony Music Labels Inc.
# 99998                    yama  Sony Music Labels Inc.
# 99999               Lexie Liu          泥鞋（北京）文化传媒有限公司
#
#                                    RecordingName              ReleaseName  \
# 0       FUTURE FT DEJ LOAF HEY THERE PROD BY DDS                #unknown#
# 1                         Keep It Cool  LUCKY3RD   Keep It Cool  LUCKY3RD
# 2                         Life Goes On  LUCKY3RD   Life Goes On  LUCKY3RD
# 3         No dudes de mi- Merengue & Bachata Mix            Mega Mix 2010
# 4                           WHEN I SEE YOU REMIX                #unknown#
# ...                                          ...                      ...
# 99995                            魔法 - Anime Size          魔法 (Anime Size)
# 99996                                         麻痺                       麻痺
# 99997                                         麻痺                       麻痺
# 99998                                         麻痺              麻痺 - Single
# 99999                              黑洞 Metropolis            无限意识 Meta Ego
#
#        Length  ListsWriters
# 0         181             0
# 1         133             0
# 2         171             0
# 3        1250             0
# 4         187             0
# ...       ...           ...
# 99995      89             1
# 99996     199             1
# 99997     199             1
# 99998     198             1
# 99999     259             1
#
# [100000 rows x 13 columns]

# %%
music_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 13 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   ISRC           100000 non-null  object
#  1   Country        100000 non-null  object
#  2   Registrant     100000 non-null  object
#  3   Year           100000 non-null  object
#  4   UsePeriod      100000 non-null  object
#  5   Platform       100000 non-null  object
#  6   Streams        100000 non-null  object
#  7   Artist         100000 non-null  object
#  8   Label          100000 non-null  object
#  9   RecordingName  100000 non-null  object
#  10  ReleaseName    100000 non-null  object
#  11  Length         100000 non-null  int64
#  12  ListsWriters   100000 non-null  int64
# dtypes: int64(2), object(11)
# memory usage: 9.9+ MB

# %%
music_df.isnull().sum()
# Out:
# ISRC             0
# Country          0
# Registrant       0
# Year             0
# UsePeriod        0
# Platform         0
# Streams          0
# Artist           0
# Label            0
# RecordingName    0
# ReleaseName      0
# Length           0
# ListsWriters     0
# dtype: int64

# %%
music_df['Streams'] = music_df['Streams'].astype(str)
music_df['Streams']=music_df['Streams'].str.replace(',','')
music_df['Streams'] = music_df['Streams'].astype(int)

# %%
music_df['UsePeriod'] = music_df['UsePeriod'].astype(str)

# %%
music_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 13 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   ISRC           100000 non-null  object
#  1   Country        100000 non-null  object
#  2   Registrant     100000 non-null  object
#  3   Year           100000 non-null  object
#  4   UsePeriod      100000 non-null  object
#  5   Platform       100000 non-null  object
#  6   Streams        100000 non-null  int32
#  7   Artist         100000 non-null  object
#  8   Label          100000 non-null  object
#  9   RecordingName  100000 non-null  object
#  10  ReleaseName    100000 non-null  object
#  11  Length         100000 non-null  int64
#  12  ListsWriters   100000 non-null  int64
# dtypes: int32(1), int64(2), object(10)
# memory usage: 9.5+ MB

# %%
month_streams = music_df.groupby(['UsePeriod', 'Platform'], as_index=False,).agg({'Streams':'sum'})

print(month_streams.head())
# Out:
#   UsePeriod      Platform    Streams
# 0                           47039078
# 1                   Apple  176108350
# 2               AudioMack   10960428
# 3               LiveXLive       6181
# 4            Midwest Tape      20656

# %%
month_streams.tail()
# Out:
#    UsePeriod Platform    Streams
# 76  5/1/2021  Melodyv    1250245
# 77  5/1/2021  Pandora   30355285
# 78  5/1/2021    Sonos       1710
# 79  5/1/2021  Spotify  557532861
# 80  5/1/2021   Trebel      15494

# %%
Month = month_streams[month_streams['UsePeriod'].isin(['1/1/2021', '2/1/2021', '3/1/2021', '4/1/2021', '5/1/2021'])]
Amazon = Month[Month['Platform'].isin(['Amazon'])]
Spotify = Month[Month['Platform'].isin(['Spotify'])]
Apple = Month[Month['Platform'].isin(['Apple'])]
Pandora = Month[Month['Platform'].isin(['Pandora'])]

# %%
Month.head()
# Out:
#    UsePeriod Platform    Streams
# 9   1/1/2021   Amazon    8216840
# 10  1/1/2021    Apple  386489626
# 11  1/1/2021   Deezer      82163
# 12  1/1/2021      GTL     469785
# 13  1/1/2021  Melodyv    1198230

# %%
plt.subplots(figsize=(10,8))
plt.plot(Spotify.UsePeriod, Spotify.Streams, color="Blue")
plt.plot(Apple.UsePeriod, Apple.Streams, color="Green")
plt.plot(Pandora.UsePeriod, Pandora.Streams, color="Red")
plt.plot(Amazon.UsePeriod, Amazon.Streams, color="Orange")
plt.title('Streams by Month', fontsize=20, fontstyle='oblique')
plt.xlabel('Month', fontsize=20, fontstyle='oblique')
plt.ylabel('Streams', fontsize=20, fontstyle='oblique')
plt.legend(["Spotify", "Apple", "Pandora", "Amazon"])
plt.show()
